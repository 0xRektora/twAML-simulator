# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

# %% [markdown]
# # Simulation results

# %%
# Case numbers
case_number = 3
version_number = 2
ifname = f"../results/inputfiles/test{case_number}.csv"
ofname = f"../results/outputs/out{case_number}_v{version_number}.csv"

# %%
# Case numbers - Max growth
case_number_MG = 1
version_number_MG = 2
ifname_MG = (
    f"../results/outputs/out_maxGrowthDeposits{case_number_MG}_v{version_number_MG}.csv"
)
ofname_MG = (
    f"../results/outputs/out_maxGrowthTWAML{case_number_MG}_v{version_number_MG}.csv"
)

# %%
ifcolumns = ["timestamp", "operation", "account", "amount", "duration"]
ifcolumnsMaxGrowth = [
    "timestamp",
    "Voting",
    "Nil",
    "amount",
    "duration",
]
ofcolumns = [
    "timestamp",
    "totalParticipants",
    "averageMagnitude",
    "totalDeposited",
    "cumulative",
]
ONE_DAY = 24 * 3600
ONE_WEEK = ONE_DAY * 7
ONE_ETHER = 10**18

input_df = pd.read_csv(ifname, header=None)
input_df.columns = ifcolumns
output_df = pd.read_csv(ofname, header=None)
output_df.columns = ofcolumns
output_df["totalDeposited"] = output_df["totalDeposited"].apply(
    lambda x: int(x) / ONE_ETHER
)
input_df_MG = pd.read_csv(ifname_MG, header=None)
input_df_MG.columns = ifcolumnsMaxGrowth
output_df_MG = pd.read_csv(ofname_MG, header=None)
output_df_MG.columns = ofcolumns
output_df_MG["totalDeposited"] = output_df_MG["totalDeposited"].apply(
    lambda x: int(x) / ONE_ETHER
)

output_df["timestamp_days"] = (output_df["timestamp"] / ONE_DAY).floordiv(1)
input_df["timestamp_days"] = (input_df["timestamp"] / ONE_DAY).floordiv(1)
input_df_MG["timestamp_days"] = (input_df_MG["timestamp"] / ONE_DAY).floordiv(1)
output_df_MG["timestamp_days"] = (output_df_MG["timestamp"] / ONE_DAY).floordiv(1)

# %%
# Input processing
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

columns = ["amount", "duration"]

for ax, column in zip(axs.flatten(), columns):
    input_df.plot(x="timestamp_days", y=column, style=".-", ax=ax, kind="bar")
    ax.set_title(column)
    ax.grid(True)

plt.tight_layout()

# %%
# Ouput processing

# %%
# # Output file
fig, axs = plt.subplots(2, 2, figsize=(10, 10))  # Creating a 2x2 grid of subplots

columns = ofcolumns[1:]

for ax, column in zip(axs.flatten(), columns):
    output_df.plot(x="timestamp_days", y=column, style=".-", ax=ax)
    ax.set_title(column)
    ax.grid(True)

plt.tight_layout()

# %%
# @hidden_cell
# Max growth scenario

# Max growth scenario
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

columns = ["amount", "duration"]
for ax, column in zip(axs.flatten(), columns):
    input_df_MG.plot(x="timestamp_days", y=column, style=".-", ax=ax)
    ax.set_title(column)
    ax.grid(True)  # Enable both major and minor grids

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
columns = ofcolumns[1:]  # Assuming 'ofcolumns' is defined elsewhere
for ax, column in zip(axs.flatten(), columns):
    output_df_MG.plot(x="timestamp_days", y=column, style=".-", ax=ax)
    ax.set_title(column)
    ax.grid(True)

plt.tight_layout()
